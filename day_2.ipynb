# %%
# - * - coding: utf-8 - * -
import pandas
df = pandas.read_excel('Data\GDP.xls')
df
# Out:
#                                               筛选栏目：全部 Unnamed: 1 Unnamed: 2  \
# 0                                                  指标         地区       数据时间
# 1                                          国内生产总值(亿元)         全国      2015年
# 2                                          国内生产总值(亿元)         全国      2014年
# 3                                      国内生产总值_当季值(亿元)         全国  2017年第三季度
# 4                                  分行业增加值构成-建筑业增加值(%)         全国      2015年
# 5                                  分行业增加值构成-建筑业增加值(%)         全国      2014年
# 6                                分行业增加值构成-农林牧渔业增加值(%)         全国      2015年
# 7                                分行业增加值构成-农林牧渔业增加值(%)         全国      2014年
# 8                                   分行业增加值构成-工业增加值(%)         全国      2015年
# 9                                   分行业增加值构成-工业增加值(%)         全国      2014年
# 10                              分行业增加值构成-批发和零售业增加值(%)         全国      2015年
# ...

# %%
import pandas
df = pandas.read_csv('Data/gdp.csv',encoding='gbk')
df
# Out:
#                                                                                筛选栏目：全部
# 指标                                                 地区  数据时间      数值       所属栏目    相关报表
# 国内生产总值(亿元)                                         全国  2015年     689052.1 年度数据    相关报表
#                                                        2014年     643974.0 年度数据    相关报表
# 国内生产总值_当季值(亿元)                                     全国  2017年第三季度 211798.1 季度数据    相关报表
# 分行业增加值构成-建筑业增加值(%)                                 全国  2015年     6.8      年度数据    相关报表
#                                                        2014年     7.0      年度数据    相关报表
# 分行业增加值构成-农林牧渔业增加值(%)                               全国  2015年     9.1      年度数据    相关报表
#                                                        2014年     9.3      年度数据    相关报表
# 分行业增加值构成-工业增加值(%)                                  全国  2015年     34.3     年度数据    相关报表
#                                                        2014年     36.3     年度数据    相关报表
# ...
