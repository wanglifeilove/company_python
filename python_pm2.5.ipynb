# %% [markdown]
# # Python抓取Pm2.5数据

# %%
'''import urllib.request
import re
import urllib.error
import time
headers = headers=("User-Agent","Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/45.0.2454.101 Safari/537.36")
data=urllib.request.urlopen(url).read().decode("utf-8")
data_time = '<div class="live_data_time">\s{1,}<p>数据更新时间：(.*?)</p>'
datatime=re.compile(data_time,re.S).findall(data)
get_pm25 = '<div class="span1">\s{1,}<div class="value">\n\s{1,}(.*?)\s{1,}</div>'
getpm25 = re.compile(get_pm25,re.S).findall(data)'''
#data_o3 = '<div class="span1>\s{1,}<div class="value">\n\s{1,}(.*)</div>'
#o3list=re.compile(data_o3,re.S).findall(data)
# Out:
# 2018-03-23 12:00:00

# %%
import urllib.request
import re
import urllib.error
import time
import matplotlib.pyplot as plt
headers = headers=("User-Agent","Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/45.0.2454.101 Safari/537.36")
opener = urllib.request.build_opener()
opener.addheaders=[headers]
urllib.request.install_opener(opener)
'''def getpm25_plt(city):
    get_pm25 = '<div class="span1">\s{1,}<div class="value">\n\s{1,}(.*?)\s{1,}</div>'
    getpm25 = re.compile(get_pm25,re.S).findall(data)
    plt.plot(getpm25[0])
    plt.show()'''
def getpm25(city):
    url = 'http://pm25.in/'+ city
    data=urllib.request.urlopen(url).read().decode("utf-8")
    print(city)
    get_pm25 = '<div class="span1">\s{1,}<div class="value">\n\s{1,}(.*?)\s{1,}</div>'
    getpm25 = re.compile(get_pm25,re.S).findall(data)
    print('AQI指数，PM2.5，PM10，  CO，    NO2，  SO2')
    print(getpm25)
    data_time = '<div class="live_data_time">\s{1,}<p>数据更新时间：(.*?)</p>'
    datatime=re.compile(data_time,re.S).findall(data)
    print(datatime)    
    f = open('data_pm25.txt','a')
    f.write(datatime[0])
    f.write(',')
    for pm25 in getpm25:
        f.write(str(pm25))
        f.write(',')
    f.write('\n')
    f.close()
    return datatime
while True:
    print('开始采集')
    getpm25('beijing')
    time.sleep(3600)
# Out:
# 开始采集
# beijing
# AQI指数，PM2.5，PM10，  CO，    NO2，  SO2
# ['257', '206', '210', '1.19', '83', '17']
# ['2018-03-27 16:00:00']
# 开始采集
# beijing
# AQI指数，PM2.5，PM10，  CO，    NO2，  SO2
# ['260', '209', '217', '1.26', '89', '17']
# ['2018-03-27 17:00:00']
# 开始采集
# beijing
# AQI指数，PM2.5，PM10，  CO，    NO2，  SO2
# ['264', '213', '230', '1.34', '99', '15']
# ['2018-03-27 18:00:00']
# 开始采集
# beijing
# AQI指数，PM2.5，PM10，  CO，    NO2，  SO2
# ['270', '219', '235', '1.48', '115', '13']
# ['2018-03-27 19:00:00']
# 开始采集
# beijing
# AQI指数，PM2.5，PM10，  CO，    NO2，  SO2
# ['290', '239', '243', '1.58', '127', '11']
# ['2018-03-27 20:00:00']
# 开始采集
# beijing
# AQI指数，PM2.5，PM10，  CO，    NO2，  SO2
# ['291', '240', '255', '1.77', '143', '10']
# ['2018-03-27 21:00:00']
# 开始采集
# beijing
# AQI指数，PM2.5，PM10，  CO，    NO2，  SO2
# ['292', '241', '262', '1.78', '135', '9']
# ['2018-03-27 22:00:00']
# 开始采集
# beijing
# AQI指数，PM2.5，PM10，  CO，    NO2，  SO2
# ['292', '241', '272', '1.81', '134', '8']
# ...
