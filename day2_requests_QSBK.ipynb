# %%
import requests
import re
def get_page(page):
    url = "http://www.qiushibaike.com/hot/page/"+str(page)+"/"
    user_agent = 'Mozilla/4.0 (compatible; MSIE 5.5; Windows NT)'
    headers = { 'User-Agent' : user_agent }
    QSBK = requests.get(url,headers = headers)
    return(QSBK.text)
def get_msg(data):
    pattern = '<div.*?class="content">(.*?)<!--.*?-->.*?</div>'
    items = re.findall(pattern,data,re.S)
    item = []
    for item in items:
        print(item)

def start(i):
    print("如需继续浏览下一页，请输入Y并按回车！")
    temp = input()
    if temp == "Y":
        date = get_page(i)
        get_msg(date)
        start(i + 1)
    else:
        print("程序结束！")
start(1)
# Out:
# 如需继续浏览下一页，请输入Y并按回车！
# Y
#
# <span>
#
#
# 小时候，我的发小 小刚性格暴烈，是个有仇报仇的主！<br/><br/>有一次，他趁一头水牛吃草的时候，在水牛屁股后面扔了一个炮仗。水牛被吓到立马给地里施肥！<br/><br/>水牛恼羞成怒去追小刚，小刚拔腿就跑。结果，水牛四蹄翻飞把小刚家里的菜地给踩了。<br/><br/>小刚暴脾气一上来，抄起地上一根木棍，就朝水牛冲去！水牛又被吓了一跳，毕竟按照惯例小孩应该怕它才对！<br/><br/>第一次正面交锋，小刚就被撞飞，趴跪在地上，那牛看到小刚对它跪着，它已经消气了，小刚还不依不挠的喊我：“扶我起来，
# …
# </span>
#
# <span class="contentForAll">查看全文</span>
#
# </div>
# </a>
#
#
# <span>
#
#
# 给婆婆花大价钱买过一个毛衫，没见过她穿，今天脑抽地想起来问了下，婆婆笑笑:我想等过几年那花色适合我了再穿！<br/>我的审美看样感人了！
#
# </span>
#
# </div>
# </a>
#
#
# <span>
#
#
# 买了条连衣裙很喜欢，回来试穿给老公，他说我审美眼光太差，我辩解到:我问店员了，她说我穿上很显瘦的！老公:店员说的没毛病，但她忘记给你说显得老气了！<br/>额……
#
# </span>
#
# </div>
# </a>
#
#
# <span>
#
#
# 小时候，我去表哥家住两天。他有录音机，我想听歌，我放磁带唱片时，听到一半，我按错键把磁带洗掉了一部分。我很紧张，纠结了半天，决定自己唱，录回去.......<br/>那天晚上，我在看书，表哥放那个唱片沉醉其中跟着哼唱，突然录音机中出现了我的声音，表哥吓得一愣，骂了一句卧  槽，连着凳子往后摔在地上...
#
# </span>
#
# </div>
# </a>
#
#
# <span>
#
#
# 木瓜姑娘，我真不知道你有孕在身啊
#
# </span>
#
# </div>
# </a>
#
#
# <span>
#
#
# 呼伦贝尔的月全食！
#
# </span>
#
# </div>
# </a>
#
#
# <span>
#
#
# A：怎样判断一个人是否真的睡着了呢？ B：亲爱的，我看一下你的手机哦。
#
# </span>
#
# </div>
# </a>
#
#
# <span>
#
#
# 小时候我揍了邻村的一个孩子，立刻遭到了一群邻村孩子的围追堵截。情急之下我钻进了两村交界，一条长五六米直径九十公分左右的排水管里…<br/>这些邻村的二货，在排水管一头派人堵着，在另一头点燃了一捆稻草…<br/>抵抗了十分钟，实在是呛的没办法，只能倒着往外爬…被他们拽着我的腿拖出排水管，按在排水沟里一顿暴打…
#
# </span>
#
# </div>
# </a>
#
#
# <span>
#
#
# 跟公司一哥们同事说:  我女朋友太重，昨晚在公司充满了电的电动自行车，居然还没到家就没电了，只好推着回去！<br/>那哥们说:  你比我好多了，我第一次骑电瓶车载着老婆，老婆坐后面，我加速，车子纹丝不动，我想应该是车坏了，让老婆下车，我好查看一下！<br/>结果，我老婆刚下车，电瓶车就蹿了出去……
#
# </span>
#
# </div>
# </a>
#
#
# <span>
#
#
#