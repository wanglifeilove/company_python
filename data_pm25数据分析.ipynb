# %% [markdown]
# # 数据分析

# %%
import matplotlib.pyplot as plt
f = open('data_pm25.txt','r')
AQI = []
pm25 = []
pm10 = []
co = []
no2 = []
so2 = []
datatime = []
for line in f.readlines():
    #print(line.strip())
    AQI.append(line[20:23])
    pm25.append(line[24:27])
    pm10.append(line[28:])
    co.append(line[31:33])
    no2.append(line[34:36])
    so2.append(line[37:39])
    datatime.append(line[8:13])
'''b = []
for i in a:
    if i not in b:
        b.append(i)'''
plt.plot(datatime,AQI)
plt.show()

# %%
import matplotlib.pyplot as plt
